# %%
import requests
import json

import pandas as pd

file = "winemag-data-130k-v2.csv"
### read data files into Data Frame
wine_df = pd.read_csv(file, index_col = 0)

# %%
wine_df.head(5)
# Out:
#      country                                        description  \
# id
# 0      Italy  Aromas include tropical fruit, broom, brimston...
# 1   Portugal  This is ripe and fruity, a wine that is smooth...
# 2         US  Tart and snappy, the flavors of lime flesh and...
# 3         US  Pineapple rind, lemon pith and orange blossom ...
# 4         US  Much like the regular bottling from 2012, this...
#
#                            designation  points  price           province  \
# id
# 0                         Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                             Avidagos      87   15.0              Douro
# 2                                  NaN      87   14.0             Oregon
# 3                 Reserve Late Harvest      87   13.0           Michigan
# 4   Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#                region_1           region_2         taster_name  \
# id
# ...

# %%
## drop all region_1 = NaN
wine_df = wine_df.dropna(subset=["region_1"])

# %%
## verify there are no more region_1 as Nan
wine_df[wine_df["region_1"]== "NaN"]
# Out:
# Empty DataFrame
# Columns: [country, description, designation, points, price, province, region_1, region_2, taster_name, taster_twitter_handle, title, variety, winery]
# Index: []

# %%
loc_df = pd.read_csv("region_data_new.csv")

# %%
loc_df.head(5)
# Out:
#               region_1 country   latitude   longitude
# 0                 Etna   Italy  37.751005   14.993435
# 1    Willamette Valley      US  44.942554 -122.933762
# 2  Lake Michigan Shore      US  43.834810  -85.072029
# 3               Alsace  France  48.318179    7.441624
# 4          Napa Valley      US  38.502469 -122.265389

# %%
len(wine_df.merge(loc_df, on= "region_1", how = "left"))
# Out:
# 108730

# %%
len(wine_df)
# Out:
# 108724

# %%
merged_wine_df = wine_df.merge(loc_df, on= "region_1", how = "left")

# %%
merged_wine_df.head(5)
# Out:
#   country_x                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1        US  Tart and snappy, the flavors of lime flesh and...
# 2        US  Pineapple rind, lemon pith and orange blossom ...
# 3        US  Much like the regular bottling from 2012, this...
# 4     Spain  Blackberry and raspberry aromas show a typical...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                                 NaN      87   14.0             Oregon
# 2                Reserve Late Harvest      87   13.0           Michigan
# 3  Vintner's Reserve Wild Child Block      87   65.0             Oregon
# 4                        Ars In Vitro      87   15.0     Northern Spain
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %%
merged_wine_df = merged_wine_df.drop('country_y', axis=1)

# %%
merged_wine_df.head(2)
# Out:
#   country_x                                        description   designation  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...  Vulkà Bianco
# 1        US  Tart and snappy, the flavors of lime flesh and...           NaN
#
#    points  price           province           region_1           region_2  \
# 0      87    NaN  Sicily & Sardinia               Etna                NaN
# 1      87   14.0             Oregon  Willamette Valley  Willamette Valley
#
#      taster_name taster_twitter_handle  \
# 0  Kerin O’Keefe          @kerinokeefe
# 1   Paul Gregutt           @paulgwine
#
#                                            title      variety     winery  \
# 0              Nicosia 2013 Vulkà Bianco  (Etna)  White Blend    Nicosia
# 1  Rainstorm 2013 Pinot Gris (Willamette Valley)   Pinot Gris  Rainstorm
#
#     latitude   longitude
# 0  37.751005   14.993435
# 1  44.942554 -122.933762

# %%
merged_wine_df.rename(columns = {"country_x": "country"}, inplace = True)

# %%
merged_wine_df.head()
# Out:
#   country                                        description  \
# 0   Italy  Aromas include tropical fruit, broom, brimston...
# 1      US  Tart and snappy, the flavors of lime flesh and...
# 2      US  Pineapple rind, lemon pith and orange blossom ...
# 3      US  Much like the regular bottling from 2012, this...
# 4   Spain  Blackberry and raspberry aromas show a typical...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                                 NaN      87   14.0             Oregon
# 2                Reserve Late Harvest      87   13.0           Michigan
# 3  Vintner's Reserve Wild Child Block      87   65.0             Oregon
# 4                        Ars In Vitro      87   15.0     Northern Spain
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %%
# save the dataframe to csv
merged_wine_df.to_csv('wine_data_new.csv', index = False)

# %%
len(merged_wine_df.dropna(subset=["latitude"]))
# Out:
# 103721

# %%
merged_wine_df = merged_wine_df.dropna(subset=["latitude"])

# %%
merged_wine_df = merged_wine_df.drop(["taster_name", "taster_twitter_handle"], axis = 1)

# %%
merged_wine_df = merged_wine_df.drop(["region_2"], axis = 1)

# %%
merged_wine_df
# Out:
#           country                                        description  \
# 0           Italy  Aromas include tropical fruit, broom, brimston...
# 1              US  Tart and snappy, the flavors of lime flesh and...
# 2              US  Pineapple rind, lemon pith and orange blossom ...
# 3              US  Much like the regular bottling from 2012, this...
# 6          France  This dry and restrained wine offers spice in p...
# 7          France  This has great depth of flavor with its fresh ...
# 8              US  Soft, supple plum envelopes an oaky structure ...
# 9          France  This is a dry wine, very spicy, with a tight, ...
# 10             US  Slightly reduced, this wine offers a chalky, t...
# 11          Italy  This is dominated by oak and oak-driven aromas...
# 12             US  Building on 150 years and six generations of w...
# 13      Argentina  Baked plum, molasses, balsamic vinegar and che...
# 14      Argentina  Raw black-cherry aromas are direct and simple ...
# ...

# %%
# save the dataframe to csv
merged_wine_df.to_csv('wine_data_new.csv', index = False)
