# %%
import requests
import json

import pandas as pd

file = "./wine-reviews/winemag-data-130k-v2.csv"
### read data files into Data Frame
wine_df = pd.read_csv(file, index_col = 0)

# %%
# count of unique region_1
len(wine_df.region_1.unique())
# Out:
# 1230

# %%
#### create a new dataframe with just the region1 and country.
locations1_df = wine_df[['region_1', 'country']]

# %%
locations1_df.head(5)
# Out:
#               region_1   country
# 0                 Etna     Italy
# 1                  NaN  Portugal
# 2    Willamette Valley        US
# 3  Lake Michigan Shore        US
# 4    Willamette Valley        US

# %%
# total length of dataset
len(locations1_df)
# Out:
# 129971

# %%
# no of records with region_1 != Nan
len(locations1_df.dropna(subset=["region_1"]))
# Out:
# 108724

# %%
#### drop rows whose region_1 is NaN
locations2_df = locations1_df.dropna(subset=["region_1"])

# %%
len(locations2_df)
# Out:
# 108724

# %%
# drop all duplicate rows ..to get unique region_1 & country
loc_df = locations2_df.drop_duplicates(subset=None, keep='first', inplace=False)

# %%
loc_df.head()
len(loc_df)
# Out:
# 1230

# %%
# import geocoder library
import geocoder

# %%
# loop thru the loc_df and find the co-ordinates for each (region, country)
coord1 =[]
for index, row in loc_df.iterrows():
        g = (row["region_1"], row["country"])
        print (g)
        g_coord = geocoder.google(g)
        coord1.append(g_coord.latlng)
# Out:
# ('Etna', 'Italy')
# ('Willamette Valley', 'US')
# ('Lake Michigan Shore', 'US')
# ('Navarra', 'Spain')
# ('Vittoria', 'Italy')
# ('Alsace', 'France')
# ('Napa Valley', 'US')
# ('Alexander Valley', 'US')
# ('Central Coast', 'US')
# ('Cafayate', 'Argentina')
# ('Mendoza', 'Argentina')
# ('Ribera del Duero', 'Spain')
# ('Virginia', 'US')
# ('Oregon', 'US')
# ('Sicilia', 'Italy')
# ('Paso Robles', 'US')
# ('Sonoma Coast', 'US')
# ('Terre Siciliane', 'Italy')
# ('Cerasuolo di Vittoria', 'Italy')
# ('Clarksburg', 'US')
# ('Beaujolais-Villages', 'France')
# ('Dry Creek Valley', 'US')
# ('Sonoma Valley', 'US')
# ('McMinnville', 'US')
# ('Puglia', 'Italy')
# ('Beaujolais', 'France')
# ('Lake County', 'US')
# ('Monticello', 'US')
# ('Brouilly', 'France')
# ('Monica di Sardegna', 'Italy')
# ('Bordeaux Blanc', 'France')
# ('North Coast', 'US')
# ('Columbia Valley (WA)', 'US')
# ('Romagna', 'Italy')
# ('Champagne', 'France')
# ('Santa Ynez Valley', 'US')
# ('Chablis', 'France')
# ('Mâcon-Milly Lamartine', 'France')
# ('California', 'US')
# ('Aglianico del Vulture', 'Italy')
# ('Howell Mountain', 'US')
# ('Calistoga', 'US')
# ('South Australia', 'Australia')
# ('Eola-Amity Hills', 'US')
# ('Rías Baixas', 'Spain')
# ('Vin de France', 'France')
# ('McLaren Vale', 'Australia')
# ('Ancient Lakes', 'US')
# ('Knights Valley', 'US')
# ('Vernaccia di San Gimignano', 'Italy')
# ('Toscana', 'Italy')
# ('Sonoma County', 'US')
# ('Juliénas', 'France')
# ('Régnié', 'France')
# ('Finger Lakes', 'US')
# ('Morellino di Scansano', 'Italy')
# ('Santa Clara Valley', 'US')
# ('Yountville', 'US')
# ('Barolo', 'Italy')
# ('Rockpile', 'US')
# ('Padthaway', 'Australia')
# ('Saint-Émilion', 'France')
# ("Barbera d'Alba", 'Italy')
# ('Santa Lucia Highlands', 'US')
# ('Spring Mountain District', 'US')
# ('Monterey', 'US')
# ('Carmel Valley', 'US')
# ('Dominio de Valdepusa', 'Spain')
# ('Santa Cruz Mountains', 'US')
# ('Chianti Classico', 'Italy')
# ('Brunello di Montalcino', 'Italy')
# ('Cahors', 'France')
# ('Edna Valley', 'US')
# ('Moulin-à-Vent', 'France')
# ('Madiran', 'France')
# ('Russian River Valley', 'US')
# ('Alto Adige', 'Italy')
# ('Arroyo Seco', 'US')
# ('Salta', 'Argentina')
# ('Anderson Valley', 'US')
# ('Campania', 'Italy')
# ('Rosso del Veronese', 'Italy')
# ('St.-Romain', 'France')
# ('Vino Nobile di Montepulciano', 'Italy')
# ('Nevada County', 'US')
# ('Côtes du Rhône', 'France')
# ('Vacqueyras', 'France')
# ('Rueda', 'Spain')
# ('Luján de Cuyo', 'Argentina')
# ('Cayuga Lake', 'US')
# ("Montepulciano d'Abruzzo", 'Italy')
# ('Santa Barbara County', 'US')
# ('Diamond Mountain District', 'US')
# ('San Marino', 'Italy')
# ('Mendocino', 'US')
# ('Vin de Pays des Côtes de Gascogne', 'France')
# ('Vino de la Tierra de Castilla y León', 'Spain')
# ('San Juan', 'Argentina')
# ('Adelaide Hills', 'Australia')
# ('Sonoma Mountain', 'US')
# ('Amador County', 'US')
# ('St. Helena', 'US')
# ('Cole Ranch', 'US')
# ('Santa Maria Valley', 'US')
# ('Torgiano', 'Italy')
# ('Veneto', 'Italy')
# ('Colli Orientali del Friuli', 'Italy')
# ('Uco Valley', 'Argentina')
# ('Monferrato', 'Italy')
# ('Dundee Hills', 'US')
# ('Perdriel', 'Argentina')
# ('Arroyo Grande Valley', 'US')
# ('Montsant', 'Spain')
# ('Saint-Estèphe', 'France')
# ('Sagrantino di Montefalco', 'Italy')
# ('Arbois', 'France')
# ('Barossa Valley', 'Australia')
# ('Tupungato', 'Argentina')
# ('Langhe', 'Italy')
# ('Roero', 'Italy')
# ("Barbera d'Asti Superiore Nizza", 'Italy')
# ('Mendocino County', 'US')
# ('Côte de Nuits-Villages', 'France')
# ('Prosecco di Valdobbiadene', 'Italy')
# ('Prosecco di Conegliano', 'Italy')
# ('Languedoc', 'France')
# ('Coteaux Varois en Provence', 'France')
# ('Cava', 'Spain')
# ('Rutherglen', 'Australia')
# ('Barossa', 'Australia')
# ('Montrachet', 'France')
# ('Heathcote', 'Australia')
# ('Clos de Vougeot', 'France')
# ('Chassagne-Montrachet', 'France')
# ('Criots-Bâtard-Montrachet', 'France')
# ('Clare Valley', 'Australia')
# ('Bianco di Custoza', 'Italy')
# ('Friuli', 'Italy')
# ('Soave', 'Italy')
# ('Collio', 'Italy')
# ('Trentino', 'Italy')
# ('Valdadige', 'Italy')
# ('Rutherford', 'US')
# ('Italy', 'Italy')
# ('Prosecco del Veneto', 'Italy')
# ('Prosecco di Conegliano e Valdobbiadene', 'Italy')
# ('Graves', 'France')
# ('Walla Walla Valley (WA)', 'US')
# ('New York', 'US')
# ('Rioja', 'Spain')
# ('North Fork of Long Island', 'US')
# ('Wahluke Slope', 'US')
# ('Templeton Gap District', 'US')
# ('Snipes Mountain', 'US')
# ('Gavi', 'Italy')
# ('Bierzo', 'Spain')
# ('Long Island', 'US')
# ('Muscadet Sèvre et Maine', 'France')
# ('Franciacorta', 'Italy')
# ('Meursault', 'France')
# ('Niagara-On-The-Lake', 'Canada')
# ('Carneros', 'US')
# ('Ribbon Ridge', 'US')
# ('Amarone della Valpolicella', 'Italy')
# ('Chambolle-Musigny', 'France')
# ('Pomerol', 'France')
# ('Cannonau di Sardegna', 'Italy')
# ('Red Mountain', 'US')
# ('Isola dei Nuraghi', 'Italy')
# ('Sta. Rita Hills', 'US')
# ('Côtes du Rhône Villages', 'France')
# ('Friuli Grave', 'Italy')
# ('El Dorado', 'US')
# ('Suisun Valley', 'US')
# ('Côtes de Provence', 'France')
# ('Lodi', 'US')
# ('Venezia Giulia', 'Italy')
# ('Yakima Valley', 'US')
# ('Monterey County', 'US')
# ('Chiles Valley', 'US')
# ('Mercurey', 'France')
# ('Calaveras County', 'US')
# ('Chehalem Mountains', 'US')
# ('Horse Heaven Hills', 'US')
# ('Umpqua Valley', 'US')
# ('Alto Adige Valle Isarco', 'Italy')
# ('Ballard Canyon', 'US')
# ('Green Valley', 'US')
# ("Coteaux d'Aix-en-Provence", 'France')
# ('Côtes de Provence Sainte-Victoire', 'France')
# ('Sierra Foothills', 'US')
# ('Yolo County', 'US')
# ("Dolcetto d'Alba", 'Italy')
# ('Bordeaux Supérieur', 'France')
# ('Costières de Nîmes', 'France')
# ('Bordeaux', 'France')
# ('Washington', 'US')
# ('Columbia Gorge (WA)', 'US')
# ('Oak Knoll District', 'US')
# ('Rogue Valley', 'US')
# ('Northern Sonoma', 'US')
# ('Soave Classico', 'Italy')
# ('Conegliano Valdobbiadene Prosecco Superiore', 'Italy')
# ('Piedmont', 'Italy')
# ('Idaho', 'US')
# ('Gambellara Classico', 'Italy')
# ('Yarra Valley', 'Australia')
# ('Great Southern', 'Australia')
# ('Mokelumne River', 'US')
# ('Los Carneros', 'US')
# ('Mount Veeder', 'US')
# ('Dogliani Superiore', 'Italy')
# ('Valencia', 'Spain')
# ('Cortona', 'Italy')
# ('Piemonte', 'Italy')
# ('Colli della Toscana Centrale', 'Italy')
# ('Livermore Valley', 'US')
# ('Valle de Uco', 'Argentina')
# ('Mâcon-Villages', 'France')
# ('Texas', 'US')
# ('Côte Chalonnaise', 'France')
# ('Chorey-lès-Beaune', 'France')
# ('Calchaquí Valley', 'Argentina')
# ('Coteaux Bourguignons', 'France')
# ('Saint-Véran', 'France')
# ('Barbaresco', 'Italy')
# ('South Eastern Australia', 'Australia')
# ('Temecula Valley', 'US')
# ('Tasmania', 'Australia')
# ('Cariñena', 'Spain')
# ('Vin Santo del Chianti Classico', 'Italy')
# ('Trento', 'Italy')
# ('Médoc', 'France')
# ('Haut-Médoc', 'France')
# ('Fronsac', 'France')
# ('Margaux', 'France')
# ('Mornington Peninsula', 'Australia')
# ('Verdicchio dei Castelli di Jesi Classico', 'Italy')
# ('Vino de la Tierra de Castilla', 'Spain')
# ('Mendocino Ridge', 'US')
# ('Rosso di Montalcino', 'Italy')
# ('Côtes de Gascogne', 'France')
# ('Côtes du Lot', 'France')
# ("Nebbiolo d'Alba", 'Italy')
# ('Beaujolais Rosé', 'France')
# ('Marsannay', 'France')
# ('Gevrey-Chambertin', 'France')
# ('Beaune', 'France')
# ('Sannio', 'Italy')
# ('Priorat', 'Spain')
# ('Bolgheri Superiore', 'Italy')
# ('Minervois', 'France')
# ('Texas High Plains', 'US')
# ('Vista Flores', 'Argentina')
# ('Australia', 'Australia')
# ('Shenandoah Valley (CA)', 'US')
# ('Blaye Côtes de Bordeaux', 'France')
# ('Jumilla', 'Spain')
# ('Coste della Sesia', 'Italy')
# ('Yorkville Highlands', 'US')
# ('Penedès', 'Spain')
# ('Greco di Tufo', 'Italy')
# ('Lugana', 'Italy')
# ('Primitivo di Manduria', 'Italy')
# ('Bardolino Classico', 'Italy')
# ('Amarone della Valpolicella Classico', 'Italy')
# ('Piave', 'Italy')
# ('Gaillac', 'France')
# ('Sancerre', 'France')
# ('Montravel', 'France')
# ('Quincy', 'France')
# ('Pouilly-Fumé', 'France')
# ('Coonawarra', 'Australia')
# ('Happy Canyon of Santa Barbara', 'US')
# ('Valdeorras', 'Spain')
# ('Bizkaiko Txakolina', 'Spain')
# ('Walla Walla Valley (OR)', 'US')
# ('Isonzo del Friuli', 'Italy')
# ("Vin de Pays d'Oc", 'France')
# ('Delle Venezie', 'Italy')
# ('Monbazillac', 'France')
# ('Patrimonio', 'France')
# ('Saumur-Champigny', 'France')
# ('Rosso di Montepulciano', 'Italy')
# ('Gers', 'France')
# ('Crémant de Jura', 'France')
# ('Vin de Liqueur', 'France')
# ('Seneca Lake', 'US')
# ('Naches Heights', 'US')
# ('Basilicata', 'Italy')
# ('Hudson River Region', 'US')
# ('Napa-Sonoma', 'US')
# ('Crémant de Bourgogne', 'France')
# ('Pouilly-Fuissé', 'France')
# ('Goulburn Valley', 'Australia')
# ('Bennett Valley', 'US')
# ('Paso Robles Willow Creek District', 'US')
# ('Montagne-Saint-Émilion', 'France')
# ('La Mancha', 'Spain')
# ('Contra Costa County', 'US')
# ('Michigan', 'US')
# ('Uclés', 'Spain')
# ('Stags Leap District', 'US')
# ("Valle d'Aosta", 'Italy')
# ('Fair Play', 'US')
# ('Menetou-Salon', 'France')
# ('Jerez', 'Spain')
# ('Fronton', 'France')
# ('Bergerac', 'France')
# ('Salento', 'Italy')
# ('Bordeaux Rosé', 'France')
# ('Pennsylvania', 'US')
# ('Les Baux de Provence', 'France')
# ('Southern Oregon', 'US')
# ('Old Mission Peninsula', 'US')
# ('Alto Adige Terlano', 'Italy')
# ('Dunnigan Hills', 'US')
# ('Bandol', 'France')
# ('Coombsville', 'US')
# ('Châteauneuf-du-Pape', 'France')
# ('Nuits-St.-Georges', 'France')
# ('Vigneti delle Dolomiti', 'Italy')
# ('Montefalco Rosso', 'Italy')
# ('Umbria', 'Italy')
# ('Faro', 'Italy')
# ('Chénas', 'France')
# ('Jurançon', 'France')
# ('Saumur', 'France')
# ('Alella', 'Spain')
# ('Bardolino Chiaretto', 'Italy')
# ('Murgia', 'Italy')
# ('Bolgheri Sassicaia', 'Italy')
# ('Pessac-Léognan', 'France')
# ('Saint-Julien', 'France')
# ('Pauillac', 'France')
# ('Oakville', 'US')
# ('Lalande de Pomerol', 'France')
# ('Delia Nivolelli', 'Italy')
# ('Cadillac Côtes de Bordeaux', 'France')
# ('Maipú', 'Argentina')
# ('Touraine', 'France')
# ('Middleburg', 'US')
# ('Reuilly', 'France')
# ('Gattinara', 'Italy')
# ('Margaret River', 'Australia')
# ('Patagonia', 'Argentina')
# ('Entre-Deux-Mers', 'France')
# ('Applegate Valley', 'US')
# ('Hermitage', 'France')
# ('Maremma', 'Italy')
# ('San Benito County', 'US')
# ('Catalunya', 'Spain')
# ('Ribeiro', 'Spain')
# ('Sauternes', 'France')
# ('San Luis Obispo County', 'US')
# ('Bolgheri', 'Italy')
# ('Alicante', 'Spain')
# ('Vin de Savoie', 'France')
# ('Almansa', 'Spain')
# ('Castillon Côtes de Bordeaux', 'France')
# ('Mediterranée', 'France')
# ('Francs Côtes de Bordeaux', 'France')
# ('Chiroubles', 'France')
# ('Saint-Amour', 'France')
# ('Ribeira Sacra', 'Spain')
# ('Leelanau Peninsula', 'US')
# ('Getariako Txakolina', 'Spain')
# ('Calatayud', 'Spain')
# ('Outer Coastal Plain', 'US')
# ('Coteaux du Languedoc', 'France')
# ('Sonoma-Napa', 'US')
# ('Langhorne Creek', 'Australia')
# ('Falerno del Massico', 'Italy')
# ('Fiano di Avellino', 'Italy')
# ('Vi de la Terra Illes Balears', 'Spain')
# ('Santa Barbara', 'US')
# ('Côtes de Bourg', 'France')
# ("Barbera d'Asti Superiore", 'Italy')
# ('Saint-Georges-Saint-Émilion', 'France')
# ('Vermentino di Sardegna', 'Italy')
# ('Bergerac Sec', 'France')
# ('Morgon', 'France')
# ("Virginia's Eastern Shore", 'US')
# ('Colli Trevigiani', 'Italy')
# ('Columbia Valley (OR)', 'US')
# ('Listrac-Médoc', 'France')
# ('Lussac Saint-Émilion', 'France')
# ("Barbera d'Asti", 'Italy')
# ('Tavel', 'France')
# ("Barbera d'Alba Superiore", 'Italy')
# ('Recioto di Soave', 'Italy')
# ('Santenay', 'France')
# ('Puligny-Montrachet', 'France')
# ('Ruché di Castagnole Monferrato', 'Italy')
# ('Valtellina Superiore', 'Italy')
# ('Oltrepò Pavese', 'Italy')
# ('Red Hills Lake County', 'US')
# ('Toro', 'Spain')
# ('Moulis-en-Médoc', 'France')
# ('Pemberton', 'Australia')
# ('Rosé de Loire', 'France')
# ('Côtes de Bordeaux', 'France')
# ('Vin Mousseux', 'France')
# ('South Coast', 'US')
# ('Yecla', 'Spain')
# ('Lake Erie', 'US')
# ('Potter Valley', 'US')
# ('Sonoma County-Napa County', 'US')
# ('Givry', 'France')
# ('Buzet', 'France')
# ('Valpolicella Classico Superiore Ripasso', 'Italy')
# ('Corse', 'France')
# ('Muscadet Côtes de Grandlieu', 'France')
# ('Terra degli Osci', 'Italy')
# ('Lambrusco di Modena', 'Italy')
# ('Montefalco Sagrantino', 'Italy')
# ('Lazio', 'Italy')
# ('Chalk Hill', 'US')
# ('Marche', 'Italy')
# ('Cerasuolo di Vittoria Classico', 'Italy')
# ('Frankland River', 'Australia')
# ('Geographe', 'Australia')
# ('Western Australia', 'Australia')
# ('Niagara Peninsula', 'Canada')
# ('Molise', 'Italy')
# ('New Jersey', 'US')
# ('Maury Sec', 'France')
# ('Côtes du Roussillon Villages Caramany', 'France')
# ('Irrouléguy', 'France')
# ('Redwood Valley', 'US')
# ('Friuli Aquileia', 'Italy')
# ('Ile de Beauté', 'France')
# ('Cucamonga Valley', 'US')
# ("Pays d'Oc", 'France')
# ('Gard', 'France')
# ('Chianti', 'Italy')
# ('Chianti Montespertoli', 'Italy')
# ('Chianti Colli Senesi', 'Italy')
# ('Bordeaux Clairet', 'France')
# ('Fleurie', 'France')
# ('Anjou Villages Brissac', 'France')
# ('Fiddletown', 'US')
# ('Bonnezeaux', 'France')
# ('Bourgogne Hautes Côtes de Nuits', 'France')
# ("Crémant d'Alsace", 'France')
# ('Mâcon-Péronne', 'France')
# ('Maranges', 'France')
# ('Augusta', 'US')
# ('Saint-Bris', 'France')
# ('New Mexico', 'US')
# ('Nevada', 'US')
# ('Adelaide Plains', 'Australia')
# ('Lessona', 'Italy')
# ('Vino Spumante', 'Italy')
# ('Boca', 'Italy')
# ('Rivesaltes', 'France')
# ('Charmes-Chambertin', 'France')
# ('Valpolicella Superiore', 'Italy')
# ('Valpolicella Classico Superiore', 'Italy')
# ('Alto Valle del Río Negro', 'Argentina')
# ('Prosecco', 'Italy')
# ('Paicines', 'US')
# ('Condrieu', 'France')
# ('Colline Pescaresi', 'Italy')
# ('Sangiovese di Romagna Superiore', 'Italy')
# ('Empordà', 'Spain')
# ('Placer County', 'US')
# ('Chianti Rufina', 'Italy')
# ('Salice Salentino', 'Italy')
# ('Mâcon-Chardonnay', 'France')
# ('Ladoix', 'France')
# ('Viré-Clessé', 'France')
# ('Campo de Borja', 'Spain')
# ('Mâcon-Fuissé', 'France')
# ('Eden Valley', 'Australia')
# ('Spain', 'Spain')
# ('La Consulta', 'Argentina')
# ('Napa County-Sonoma County', 'US')
# ('Solano County', 'US')
# ('Colline Novaresi', 'Italy')
# ('Adelaide', 'Australia')
# ('Agrelo', 'Argentina')
# ('Veneto Orientale', 'Italy')
# ('Vin de Pays des Cévennes', 'France')
# ('Luberon', 'France')
# ('Adelaida District', 'US')
# ('Calabria', 'Italy')
# ('Taurasi', 'Italy')
# ('Eloro', 'Italy')
# ('Faugères', 'France')
# ('Crémant de Limoux', 'France')
# ('Valdobbiadene Prosecco Superiore', 'Italy')
# ('Irpinia', 'Italy')
# ('Picpoul de Pinet', 'France')
# ('Côtes du Marmandais', 'France')
# ('Coteaux du Layon', 'France')
# ('Cornas', 'France')
# ('Chalone', 'US')
# ('Savennières', 'France')
# ('Ventoux', 'France')
# ('Taburno', 'Italy')
# ('Chinon', 'France')
# ('Sebino', 'Italy')
# ('Vouvray', 'France')
# ('Columbia Gorge (OR)', 'US')
# ("Trebbiano d'Abruzzo", 'Italy')
# ('Crémant de Loire', 'France')
# ('Terra Alta', 'Spain')
# ('Victoria', 'Australia')
# ('Valdepeñas', 'Spain')
# ('Friuli Colli Orientali', 'Italy')
# ('Vin Santo del Chianti', 'Italy')
# ('Vosne-Romanée', 'France')
# ('Valdobbiadene Superiore di Cartizze', 'Italy')
# ('Recioto della Valpolicella Classico', 'Italy')
# ('Gavi di Gavi', 'Italy')
# ('Roero Arneis', 'Italy')
# ('Dolcetto di Dogliani', 'Italy')
# ('Neuquén', 'Argentina')
# ("Moscato d'Asti", 'Italy')
# ('Saint-Nicolas-de-Bourgueil', 'France')
# ('Lake Chelan', 'US')
# ('Roussette de Savoie', 'France')
# ('Maremma Toscana', 'Italy')
# ('Rattlesnake Hills', 'US')
# ('Alta Langa', 'Italy')
# ('El Dorado County', 'US')
# ('Napa County', 'US')
# ('Côtes de Nuits Villages', 'France')
# ('Bourgogne Hautes Côtes de Beaune', 'France')
# ('Saint-Aubin', 'France')
# ('Marin County', 'US')
# ('Barsac', 'France')
# ('Conero', 'Italy')
# ('Menfi', 'Italy')
# ('Montilla-Moriles', 'Spain')
# ('Río Negro Valley', 'Argentina')
# ('Pernand-Vergelesses', 'France')
# ('Málaga', 'Spain')
# ('Auxey-Duresses', 'France')
# ('Savigny-lès-Beaune', 'France')
# ('Mâcon-Verze', 'France')
# ('Saint-Joseph', 'France')
# ('Vin de Pays Var', 'France')
# ('Frascati Superiore', 'Italy')
# ('Volnay', 'France')
# ('Fort Ross-Seaview', 'US')
# ('Mt. Harlan', 'US')
# ('Quarts de Chaume', 'France')
# ("Lambrusco dell'Emilia", 'Italy')
# ('Colli Aprutini', 'Italy')
# ("Montepulciano d'Abruzzo Colline Teramane", 'Italy')
# ('Valpolicella Superiore Ripasso', 'Italy')
# ('Valpolicella Ripasso', 'Italy')
# ('Cheverny', 'France')
# ('Forlì', 'Italy')
# ('Colli Martani', 'Italy')
# ('Cienega Valley', 'US')
# ('Temecula', 'US')
# ('Ghemme', 'Italy')
# ('Carignano del Sulcis', 'Italy')
# ('Alghero', 'Italy')
# ('Anjou', 'France')
# ('Pécharmant', 'France')
# ('Minervois La Liviniere', 'France')
# ('Corbières', 'France')
# ('Marsala', 'Italy')
# ('Grand Valley', 'US')
# ('Colorado', 'US')
# ('Okanagan Valley', 'Canada')
# ('Clarendon', 'Australia')
# ('Côtes du Jura', 'France')
# ('Corton Les Renardes', 'France')
# ('Coteaux du Giennois', 'France')
# ('Aloxe-Corton', 'France')
# ('Rosso Conero', 'Italy')
# ('Falerio', 'Italy')
# ('Verdicchio dei Castelli di Jesi', 'Italy')
# ('Rosso Piceno', 'Italy')
# ('Hunter Valley', 'Australia')
# ('La Rioja', 'Argentina')
# ('Central Ranges', 'Australia')
# ('Coteaux Varois', 'France')
# ('Val di Cornia Suvereto', 'Italy')
# ('Orvieto Classico Superiore', 'Italy')
# ('Vin de Pays du Val de Loire', 'France')
# ('Cochise County', 'US')
# ('Vino de la Tierra Altiplano de Sierra Nevada', 'Spain')
# ('Pine Mountain-Cloverdale Peak', 'US')
# ('Costers del Segre', 'Spain')
# ('Verdicchio dei Castelli di Jesi Classico Superiore', 'Italy')
# ('Custoza Superiore', 'Italy')
# ('Veronese', 'Italy')
# ('Val di Neto', 'Italy')
# ('Big Valley District-Lake County', 'US')
# ('San Antonio Valley', 'US')
# ('Bourgogne', 'France')
# ('Petit Chablis', 'France')
# ('Sierra Pelona Valley', 'US')
# ('Valpolicella', 'Italy')
# ('San Luis Obispo', 'US')
# ('Famatina Valley', 'Argentina')
# ('Bâtard-Montrachet', 'France')
# ('Chevalier-Montrachet', 'France')
# ('Atlas Peak', 'US')
# ('Puisseguin Saint-Émilion', 'France')
# ('Asprinio di Aversa', 'Italy')
# ('Orvieto Classico', 'Italy')
# ('Bardolino', 'Italy')
# ('Orcia', 'Italy')
# ('Limestone Coast', 'Australia')
# ('Mâcon-Azé', 'France')
# ('Pyrenees', 'Australia')
# ('Prosecco Superiore di Cartizze', 'Italy')
# ('High Valley', 'US')
# ('Lambrusco Grasparossa di Castelvetro', 'Italy')
# ('San Bernabe', 'US')
# ('Vermentino di Gallura', 'Italy')
# ('Ben Lomond Mountain', 'US')
# ('Argentina', 'Argentina')
# ('Morey-Saint-Denis', 'France')
# ('Missouri', 'US')
# ('Southeastern New England', 'US')
# ('Grand River Valley', 'US')
# ('Sonoita', 'US')
# ('Corton-Charlemagne', 'France')
# ('Emilia', 'Italy')
# ('King Valley', 'Australia')
# ('Pommard', 'France')
# ('Costa Toscana', 'Italy')
# ('Albana di Romagna', 'Italy')
# ('Grands-Echezeaux', 'France')
# ('Moscadello di Montalcino', 'Italy')
# ('Mazis-Chambertin', 'France')
# ('The Hamptons, Long Island', 'US')
# ('Vin de Pays du Comté Tolosan', 'France')
# ('Somontano', 'Spain')
# ('Tierra del Viños de Zamora', 'Spain')
# ('Niagara Escarpment', 'Canada')
# ('Central Victoria', 'Australia')
# ('Bordeaux Côtes de Francs ', 'France')
# ('Shenandoah Valley', 'US')
# ('Savoie', 'France')
# ('Palette', 'France')
# ('Var', 'France')
# ('Val de Loire', 'France')
# ('Coteaux du Languedoc Pic Saint Loup', 'France')
# ('Primitivo del Salento', 'Italy')
# ('Tarragona', 'Spain')
# ('Valpolicella Classico', 'Italy')
# ('Hautes Côtes de Nuits', 'France')
# ('La Clape', 'France')
# ('Vin Santo di Montepulciano', 'Italy')
# ('Santa Barbara-Monterey', 'US')
# ('Gigondas', 'France')
# ('Conca de Barberà', 'Spain')
# ('Beamsville Bench', 'Canada')
# ('Lessini Durello', 'Italy')
# ('Bourgueil', 'France')
# ('Saint-Croix-du-Mont', 'France')
# ('Lake Erie North Shore', 'Canada')
# ('Prosecco Treviso', 'Italy')
# ('Côte de Brouilly', 'France')
# ('Mâcon-Pierreclos', 'France')
# ('Salina', 'Italy')
# ('Sainte-Foy Bordeaux', 'France')
# ('Saint-Chinian', 'France')
# ('Crozes-Hermitage', 'France')
# ('Southern Flinders Ranges', 'Australia')
# ('Napa-Carneros', 'US')
# ('Catalonia', 'Spain')
# ('Pouilly-Vinzelles', 'France')
# ('Lago di Corbara', 'Italy')
# ('Macon-Bussières', 'France')
# ('Colli Euganei', 'Italy')
# ('Offida Pecorino', 'Italy')
# ('Passito di Pantelleria', 'Italy')
# ('Illinois', 'US')
# ("Sant'Antimo", 'Italy')
# ('Vin Santo del Chianti Rufina', 'Italy')
# ('Corse Porto Vecchio', 'France')
# ('Côtes du Roussillon Villages Tautavel', 'France')
# ('Côtes du Roussillon Villages', 'France')
# ('Aglianico del Taburno', 'Italy')
# ('Castel del Monte', 'Italy')
# ('Colli di Faenza', 'Italy')
# ('Sangiovese di Romagna', 'Italy')
# ('Mâcon', 'France')
# ('Fixin', 'France')
# ('Sforzato di Valtellina', 'Italy')
# ('Corton', 'France')
# ('Latricières-Chambertin', 'France')
# ('Premieres Côtes de Blaye', 'France')
# ('Montagny', 'France')
# ('Vin de Pays des Côtes Catalanes', 'France')
# ('Malibu-Newton Canyon', 'US')
# ('Vino de la Tierra Contraviesa Alpujarra', 'Spain')
# ('Mount Harlan', 'US')
# ('Côtes du Tarn', 'France')
# ('Terrazze Retiche di Sondrio', 'Italy')
# ('Pla de Bages', 'Spain')
# ('Côtes de Provence La Londe', 'France')
# ('Coteaux du Layon Chaume', 'France')
# ('Sonoma-Napa-Mendocino', 'US')
# ("Dolcetto d'Acqui", 'Italy')
# ('San Francisco Bay', 'US')
# ('Nagambie Lakes', 'Australia')
# ('Côtes de Bergerac', 'France')
# ('Pacherenc du Vic Bilh', 'France')
# ('Chelan County', 'US')
# ('Riverina', 'Australia')
# ('California Other', 'US')
# ('Saddle Rock-Malibu', 'US')
# ('Echézeaux', 'France')
# ('La Grande Rue', 'France')
# ('Clos de la Roche', 'France')
# ('Vougeot', 'France')
# ('Wrattonbully', 'Australia')
# ('Mâcon-Vergisson', 'France')
# ('Lambrusco di Sorbara', 'Italy')
# ('Mâcon-Cruzille', 'France')
# ('Moon Mountain District Sonoma County', 'US')
# ('Collines Rhôdaniennes', 'France')
# ('Loazzolo', 'Italy')
# ('Humboldt County', 'US')
# ('Clairette de Die Méthode Dioise Ancestrale', 'France')
# ('Jurançon Sec', 'France')
# ('Curtefranca', 'Italy')
# ('Monteregio di Massa Marittima', 'Italy')
# ('Napa-Sonoma-Marin', 'US')
# ('Maury', 'France')
# ('Muscat de Rivesaltes', 'France')
# ('Montecucco', 'Italy')
# ('Vin de Table Francais', 'France')
# ('Santa Clara County', 'US')
# ('Atlantique', 'France')
# ('Muscadet', 'France')
# ('Sierra de Salamanca', 'Spain')
# ('Chignin-Bergeron', 'France')
# ('Beaujolais Blanc', 'France')
# ('Mâcon La Roche Vineuse', 'France')
# ('Côtes du Roussillon Les Aspres', 'France')
# ('Côtes du Roussillon', 'France')
# ('Beaujolais-Leynes', 'France')
# ('Côtes de Duras', 'France')
# ('Fitou', 'France')
# ('Puget Sound', 'US')
# ('Chambertin Clos de Bèze', 'France')
# ('Corton-Rognet', 'France')
# ('Corton Vergennes', 'France')
# ('Chapelle-Chambertin', 'France')
# ('Dogliani', 'Italy')
# ('Anjou Villages', 'France')
# ('Cadillac', 'France')
# ('Sable de Camargue', 'France')
# ('Pago de Arínzano', 'Spain')
# ('Beneventano', 'Italy')
# ('Monti Lessini', 'Italy')
# ('McLaren Vale-Adelaide Hills', 'Australia')
# ('Colli Piacentini', 'Italy')
# ('Martina', 'Italy')
# ('Lacryma Christi del Vesuvio', 'Italy')
# ('Côtes Catalanes', 'France')
# ('Vin de Pays Cité de Carcassonne', 'France')
# ('Solano County Green Valley', 'US')
# ('Friuli Isonzo', 'Italy')
# ('Penisola Sorrentina', 'Italy')
# ('California-Oregon', 'US')
# ('Clear Lake', 'US')
# ('Guenoc Valley', 'US')
# ('Terre del Volturno', 'Italy')
# ("Coteaux d'Ancenis", 'France')
# ('Cabernet de Saumur', 'France')
# ('Utiel-Requena', 'Spain')
# ('Soave Colli Scaligeri', 'Italy')
# ('Napa County-Sonoma County-San Joaquin County', 'US')
# ('Bourgogne Gamay', 'France')
# ('Terre di Franciacorta', 'Italy')
# ('Falanghina del Sannio', 'Italy')
# ('Rosso di Toscana', 'Italy')
# ('Côtes de Castillon', 'France')
# ('Carneros-Napa Valley', 'US')
# ('Lenswood', 'Australia')
# ('Côte de Beaune', 'France')
# ("Rosé d'Anjou", 'France')
# ("St. David's Bench", 'Canada')
# ('Coteaux du Vendômois', 'France')
# ('Valpolicella Ripasso Classico', 'Italy')
# ('Chianti Colli Fiorentini', 'Italy')
# ('Swan Creek', 'US')
# ('Tierra de León', 'Spain')
# ('Mudgee', 'Australia')
# ('Orange', 'Australia')
# ('New South Wales', 'Australia')
# ('Rosso Piceno Superiore', 'Italy')
# ('Offida Passerina', 'Italy')
# ('Recioto di Soave Classico', 'Italy')
# ('Montlouis-sur-Loire', 'France')
# ('Vin de Pays du Lot', 'France')
# ('Venezie', 'Italy')
# ('Riviera Ligure di Ponente', 'Italy')
# ('Tulum Valley', 'Argentina')
# ('Pompeiano', 'Italy')
# ('Epomeo', 'Italy')
# ('Roccamonfina', 'Italy')
# ('Marcillac', 'France')
# ('Tierra de Castilla', 'Spain')
# ('El Pomar District', 'US')
# ('Galluccio', 'Italy')
# ('Bourgogne Epineuil', 'France')
# ('Colli di Salerno', 'Italy')
# ('Tuolumne County', 'US')
# ('Côtes-du-Ventoux', 'France')
# ('Tarantino', 'Italy')
# ('Santa Margarita Ranch', 'US')
# ("Brachetto d'Acqui", 'Italy')
# ('Saint-Mont', 'France')
# ('Crémant de Bordeaux', 'France')
# ('Mâcon-Lugny', 'France')
# ('Dolcetto di Monferrato', 'Italy')
# ('Malibu Coast', 'US')
# ('Rully', 'France')
# ('Pavia', 'Italy')
# ('Asti', 'Italy')
# ('Carmignano', 'Italy')
# ('Bullas', 'Spain')
# ('Bonnes-Mares', 'France')
# ('McDowell Valley', 'US')
# ('Rasteau', 'France')
# ('Cilento', 'Italy')
# ('Vin de Pays des Maures', 'France')
# ('Yadkin Valley', 'US')
# ("Costa d'Amalfi", 'Italy')
# ('Iowa', 'US')
# ('Premieres Côtes de Bordeaux', 'France')
# ('Chianti Montalbano', 'Italy')
# ('Elkton Oregon', 'US')
# ('Bourgogne Aligoté', 'France')
# ('Saint-Romain', 'France')
# ('Lugana Superiore', 'Italy')
# ('Napa-Mendocino-Sonoma-Marin', 'US')
# ('Cesanese del Piglio', 'Italy')
# ('Muscat de Saint-Jean de Minervois', 'France')
# ('Banyuls', 'France')
# ('Friuli Venezia Giulia', 'Italy')
# ('Monterey-Santa Barbara', 'US')
# ('Sonoma County-Monterey County-Napa County', 'US')
# ('Rubicone', 'Italy')
# ('Cévennes', 'France')
# ('Vittoria Frappato', 'Italy')
# ('Muscat de Beaumes de Venise', 'France')
# ('Ribera del Júcar', 'Spain')
# ('Sonoma-Mendocino', 'US')
# ('Mâcon-Uchizy', 'France')
# ('Colli di Luni', 'Italy')
# ('Soave Classico Superiore', 'Italy')
# ('Corton Grèves', 'France')
# ('Barbera del Monferrato', 'Italy')
# ('Copertino', 'Italy')
# ('Alta Mesa', 'US')
# ('Coteaux de Verdon', 'France')
# ('Lirac', 'France')
# ('Kelsey Bench-Lake County', 'US')
# ('Valpolicella Valpantena Superiore', 'Italy')
# ('San Lucas', 'US')
# ('British Columbia', 'Canada')
# ('Manchuela', 'Spain')
# ('Biferno Rosso', 'Italy')
# ('Sonoma County-Lake County', 'US')
# ('France', 'France')
# ('Colli Perugini', 'Italy')
# ("Aleatico dell'Elba", 'Italy')
# ('Corbières-Boutenac', 'France')
# ('Vin Pétillant', 'France')
# ('Ohio', 'US')
# ('Vin de Pays du Val de Cesse', 'France')
# ('Saussignac', 'France')
# ('Limoux', 'France')
# ('Paso Robles Highlands District', 'US')
# ('Madrid', 'Spain')
# ('Colli Tortonesi', 'Italy')
# ('Barco Reale di Carmignano', 'Italy')
# ('Vino de Mesa', 'Spain')
# ('Sonoma County-Monterey County', 'US')
# ('Pouilly-Loché', 'France')
# ('Noto', 'Italy')
# ('Campi Flegrei', 'Italy')
# ('Bendigo', 'Australia')
# ("Vin de Pays de L'Aude", 'France')
# ('Terre di Chieti', 'Italy')
# ('Buenos Aires', 'Argentina')
# ('Vin de Pays du Gard', 'France')
# ('Colline Teatine', 'Italy')
# ("Cerasuolo d'Abruzzo", 'Italy')
# ('Pomino', 'Italy')
# ('Côte Rôtie', 'France')
# ('Vermont', 'US')
# ('Garda Classico', 'Italy')
# ('Montenetto di Brescia', 'Italy')
# ('Lombardy', 'Italy')
# ('Benaco Bresciano', 'Italy')
# ('Musigny', 'France')
# ('Chambertin', 'France')
# ('Clos Saint-Denis', 'France')
# ('Malvasia delle Lipari', 'Italy')
# ('Côtes de Thongue', 'France')
# ('Côtes du Frontonnais', 'France')
# ('Ventura County', 'US')
# ('Marca Trevigiana', 'Italy')
# ('Colli di Conegliano', 'Italy')
# ('Chianti Colli Aretini', 'Italy')
# ('Monterrei', 'Spain')
# ('Mendocino-Lake', 'US')
# ('Bramaterra', 'Italy')
# ('Monterey-Santa Cruz', 'US')
# ('Teroldego Rotaliano', 'Italy')
# ('North Carolina', 'US')
# ('Cortese di Gavi', 'Italy')
# ('York Mountain', 'US')
# ('Touraine Amboise', 'France')
# ('Colli Bolognesi', 'Italy')
# ('Lambrusco Reggiano', 'Italy')
# ('Emilia-Romagna', 'Italy')
# ('Château-Chalon', 'France')
# ('Mâcon-Mancey', 'France')
# ('Irancy', 'France')
# ('Cigales', 'Spain')
# ('Assisi', 'Italy')
# ('Savennières-Roche-Aux-Moines', 'France')
# ('Jujuy', 'Argentina')
# ('Montescudaio', 'Italy')
# ('Galatina', 'Italy')
# ('Cirò', 'Italy')
# ('Vin de Pays des Portes de Méditerranée', 'France')
# ('Alcamo', 'Italy')
# ('Soave Superiore', 'Italy')
# ('Brulhois', 'France')
# ('Mâcon-Loché', 'France')
# ('Mâcon-Vinzelles', 'France')
# ('Chianti Superiore', 'Italy')
# ('Rosazzo', 'Italy')
# ('Orvieto', 'Italy')
# ('Verdicchio di Matelica', 'Italy')
# ('Columbia Valley-Walla Walla Valley', 'US')
# ('Gutturnio Colli Piacentini', 'Italy')
# ('Valtènesi', 'Italy')
# ('Madera', 'US')
# ('Ardèche', 'France')
# ('Barbera del Monferrato Superiore', 'Italy')
# ('Mâcon-Charnay', 'France')
# ('Sonoma', 'US')
# ('Mount Barker', 'Australia')
# ('Corton-Pougets', 'France')
# ('Cérons', 'France')
# ('Coteaux du Layon Saint Aubin', 'France')
# ('Gioia del Colle', 'Italy')
# ('Kentucky', 'US')
# ('Prince Edward County', 'Canada')
# ('San Francisco Bay-Livermore Valley', 'US')
# ('Extremadura', 'Spain')
# ('Vino da Tavola', 'Italy')
# ('Southern Fleurieu', 'Australia')
# ('Clements Hills', 'US')
# ('Vinos de Madrid', 'Spain')
# ('Pouilly-sur-Loire', 'France')
# ('Custoza', 'Italy')
# ('Contea di Sclafani', 'Italy')
# ("Dolcetto di Diano d'Alba", 'Italy')
# ('Vin de Pays de la Méditerranée', 'France')
# ("Vin de Pays de l'Ile de Beauté", 'France')
# ('Nuragus di Cagliari', 'Italy')
# ('Blanquette de Limoux', 'France')
# ('Asolo Prosecco Superiore', 'Italy')
# ('Venezia', 'Italy')
# ('Sonoma County-San Joaquin County', 'US')
# ('Clairette de Bellegarde', 'France')
# ('Provincia di Pavia', 'Italy')
# ("Montepulciano d'Abruzzo Cerasuolo", 'Italy')
# ('Colline Lucchesi', 'Italy')
# ('Emporadà-Costa Brava', 'Spain')
# ('Fara', 'Italy')
# ('Lison-Pramaggiore', 'Italy')
# ('Côtes du Luberon', 'France')
# ('Lambrusco Salamino di Santa Croce', 'Italy')
# ('Recioto della Valpolicella', 'Italy')
# ('Canon-Fronsac', 'France')
# ('Western Connecticut Highlands', 'US')
# ('River Junction', 'US')
# ('Passito di Noto', 'Italy')
# ('Vin de Pays des Alpilles', 'France')
# ('Grampians', 'Australia')
# ('Currency Creek', 'Australia')
# ('Cour-Cheverny', 'France')
# ('Muscadet Sèvre et Maine Clisson', 'France')
# ('Amarone della Valpolicella Valpantena', 'Italy')
# ('Aude Hauterive', 'France')
# ('Ribera del Guadiana', 'Spain')
# ('Toledo', 'Spain')
# ('Monterey-Santa Barbara-Sonoma', 'US')
# ('Valtellina', 'Italy')
# ('Vi de la Terra Mallorca', 'Spain')
# ('Abruzzo', 'Italy')
# ('Columbia Valley', 'US')
# ('Piccadilly Valley', 'Australia')
# ('Lake County-Mendocino County', 'US')
# ('Côte de Beaune-Villages', 'France')
# ('Oregon Other', 'US')
# ('Meursault-Blagny', 'France')
# ('Sonoma County-Monterey County-Santa Barbara County', 'US')
# ('Yamhill County', 'US')
# ('Mendocino-Lake County-Napa', 'US')
# ('Beechworth', 'Australia')
# ('Vin de Pays de Vaucluse', 'France')
# ('Montecarlo', 'Italy')
# ('Monterey-San Luis Obispo-Santa Barbara', 'US')
# ('Contessa Entellina', 'Italy')
# ('Moscato di Noto', 'Italy')
# ("Diano d'Alba", 'Italy')
# ('Vino de la Tierra del Bajo Aragón', 'Spain')
# ('Chignin', 'France')
# ('Controguerra', 'Italy')
# ('San Carlos', 'Argentina')
# ('Manzanilla-Sanlúcar de Barrameda', 'Spain')
# ('Valli di Porto Pino', 'Italy')
# ('Falanghina del Beneventano', 'Italy')
# ('Swan Hill', 'Australia')
# ('Falerio dei Colli Ascolani', 'Italy')
# ('Erbaluce di Caluso', 'Italy')
# ('Mamertino', 'Italy')
# ('Mâcon Solutré', 'France')
# ("Civitella d'Agliano", 'Italy')
# ('Landes', 'France')
# ('Mâcon-Davayé', 'France')
# ('Pedernal Valley', 'Argentina')
# ('Breganze', 'Italy')
# ('Tehama County', 'US')
# ('Siracusa', 'Italy')
# ('Vin de Pays du Jardin de la France', 'France')
# ('Ischia', 'Italy')
# ('Murray-Darling', 'Australia')
# ('Saint-Péray', 'France')
# ('Castilla La Mancha', 'Spain')
# ('Muscadet Coteaux de la Loire', 'France')
# ('Pays de Loire', 'France')
# ('Carema', 'Italy')
# ('Valpolicella Valpantena', 'Italy')
# ('Ramona Valley', 'US')
# ('Napa County-Lake County', 'US')
# ('Prosecco di Valdobbiadene Superiore', 'Italy')
# ('Colli Etruria Centrale', 'Italy')
# ("Vin de Pays de l'Atlantique", 'France')
# ('Côtes de Forez', 'France')
# ('Monthélie', 'France')
# ('Clos de Lambrays', 'France')
# ('Clos de Tart', 'France')
# ('Romanée-St.-Vivant', 'France')
# ('Arizona', 'US')
# Status code Unknown from https://maps.googleapis.com/maps/api/geocode/json: ERROR - HTTPSConnectionPool(host='maps.googleapis.com', port=443): Max retries exceeded with url: /maps/api/geocode/json?address=Arizona&address=US&bounds=&components=&region=&language= (Caused by SSLError(SSLError("bad handshake: SysCallError(54, 'ECONNRESET')",),))
# ('Short Hills Bench', 'Canada')
# ('Vin Doux Naturel Rasteau', 'France')
# ('Aglianico del Beneventano', 'Italy')
# ('Vin de Pays de la Haute Vallée du Gassac', 'France')
# ('Zonda Valley', 'Argentina')
# ('Barbera di Piemonte', 'Italy')
# ('Périgord', 'France')
# ('Lanzarote', 'Spain')
# ('Châteaumeillant', 'France')
# ('Napa', 'US')
# ('Erice', 'Italy')
# ('Tuscany', 'Italy')
# ('Similkameen Valley', 'Canada')
# ('Bourgogne Côtes d’Auxerre', 'France')
# ('Nardò', 'Italy')
# ('Donnici', 'Italy')
# ('Cabardes', 'France')
# ('Dolcetto di Dogliani Superiore', 'Italy')
# ('Bergerac Rosé', 'France')
# ('Lamezia', 'Italy')
# ('Trentino Superiore', 'Italy')
# ('Grave del Friuli', 'Italy')
# ('Hautes Cotes de Beaune', 'France')
# ('Mâcon-Prissé', 'France')
# ('Vino de la Tierra de Cádiz', 'Spain')
# ('Central Valley', 'US')
# ('Vin Santo di Carmignano', 'Italy')
# ('Bienvenues Bâtard-Montrachet', 'France')
# ('Ramandolo', 'Italy')
# ('Vino de la Tierra de Zamora', 'Spain')
# ('Lot', 'France')
# ('Garda', 'Italy')
# ('Napa-Monterey-Mendocino', 'US')
# ('Brindisi', 'Italy')
# ('Western Plains', 'Australia')
# ('Vino de la Tierra de Castelló', 'Spain')
# ('Kangaroo Island', 'Australia')
# ('Burgundy', 'France')
# ('Casorzo', 'Italy')
# ('Rosso di Cerignola', 'Italy')
# ("Dolcetto d'Asti", 'Italy')
# ("Sant' Agata dei Goti", 'Italy')
# ('McLaren Vale-Langhorne Creek', 'Australia')
# ('Mentrida', 'Spain')
# ('Monreale', 'Italy')
# ('Monferrato Bianco', 'Italy')
# ('Béarn', 'France')
# ('Torgiano Rosso Riserva', 'Italy')
# ('Arribes del Duero', 'Spain')
# ('Finca Élez', 'Spain')
# ('Moulis', 'France')
# ('Lime Kiln Valley', 'US')
# ('Mâcon Chaintré', 'France')
# ('Vino da Mesa de Toledo', 'Spain')
# ('Moscato di Pantelleria', 'Italy')
# ('Amador-Napa', 'US')
# ('Hilltops', 'Australia')
# ('Polk County', 'US')
# ('Barossa-Langhorne Creek', 'Australia')
# ('Alpilles', 'France')
# ('Currency Creek-McLaren Vale', 'Australia')
# ('Coteaux du Lyonnais', 'France')
# ('Sardinia', 'Italy')
# ('Gippsland', 'Australia')
# ('Strathbogie Ranges', 'Australia')
# ('Colline Teramane', 'Italy')
# ('Vino de la Tierra Ribera del Gállego-Cinco Villas', 'Spain')
# ('Monterey County-Napa County-Sonoma County', 'US')
# ('Côte Roannaise', 'France')
# ('Côtes de Thau', 'France')
# ('Antelope Valley of the California High Desert', 'US')
# ('Moscato di Trani', 'Italy')
# ('Napa Valley-Paso Robles', 'US')
# ('Clare Valley-Coonawarra', 'Australia')
# ('Falanghina del Molise', 'Italy')
# ('Corton-Bressandes', 'France')
# ('Medrano', 'Argentina')
# ('Lake County-Sonoma County', 'US')
# ('Valpolicella Ripasso Valpantena', 'Italy')
# ('Gaillac Doux', 'France')
# ('Circeo', 'Italy')
# ('Gundagai', 'Australia')
# ('Vin de Pays des Coteaux de Bessilles', 'France')
# ('Mount Barker & Margaret River', 'Australia')
# ('Mazoyeres-Chambertin', 'France')
# ('Altos de Mendoza', 'Argentina')
# ('Coteaux du Languedoc-Pézenas', 'France')
# ('Cirò Classico', 'Italy')
# ('Bardolino Classico Superiore', 'Italy')
# ('Vino de Calidad de Tierras de León', 'Spain')
# ("Cabernet d'Anjou", 'France')
# ('Valpolicella Ripasso Valpantena Superiore', 'Italy')
# ('McLaren Vale-Padthaway', 'Australia')
# ('Mendocino-Amador', 'US')
# ('Vallée du Paradis', 'France')
# ('San Rafael', 'Argentina')
# ('Sovana', 'Italy')
# ('Vesuvio', 'Italy')
# ("Dolcetto d'Alba Superiore", 'Italy')
# ('Tumbarumba', 'Australia')
# ('Henty', 'Australia')
# ('Côtes de Saint-Mont', 'France')
# ('Laudun', 'France')
# ('Saint-Chinian-Roquebrun', 'France')
# ('San Martino della Battaglia', 'Italy')
# ('Geelong', 'Australia')
# ('Corton Perrières', 'France')
# ('Alpine Valleys', 'Australia')
# ('Chianti Colli Pisani', 'Italy')
# ('Coteaux du Layon Beaulieu', 'France')
# ('Primitivo del Tarantino', 'Italy')
# ('Napa-Amador', 'US')
# ('Napa County-Sonoma County-Lake County', 'US')
# ("Vin de Pays de L'Herault", 'France')
# ('Montello e Colli Asolani', 'Italy')
# ('Nasco di Cagliari', 'Italy')
# ('Charentais', 'France')
# ('Montefalco', 'Italy')
# ('Santa Cruz County', 'US')
# ('Sonoma-Santa Barbara-Mendocino', 'US')
# ('Napa-Mendocino-Sonoma', 'US')
# ('Vin de Pays de France', 'France')
# ('Massachusetts', 'US')
# ('Canada', 'Canada')
# ('Frascati', 'Italy')
# ('Alta Valle della Greve', 'Italy')
# ('Southern Highlands', 'Australia')
# ('La Romanée', 'France')
# ("Aglianico d'Irpinia", 'Italy')
# ('Lake-Sonoma-Napa', 'US')
# ('Vin de Pays de Montferrand', 'France')
# ('Isle St. George', 'US')
# ('Clairette de Die', 'France')
# ('Clare Valley-Eden Valley', 'Australia')
# ('Gutturnio Classico Superiore', 'Italy')
# ('Strevi', 'Italy')
# ('Australia-New Zealand', 'Australia')
# ('Riverland', 'Australia')
# ('Sardon de Duero', 'Spain')
# ('Texoma', 'US')
# ('Capay Valley', 'US')
# ('Fleurieu Peninsula', 'Australia')
# ('Cacc’e Mmitte di Lucera', 'Italy')
# ('Sonoma-Napa-Monterey', 'US')
# ('Collioure', 'France')
# ('Saint Guilhem le Désert', 'France')
# ('Catalanesca del Monte Somma', 'Italy')
# ('Hawaii', 'US')
# ('San Gimignano', 'Italy')
# ('Bourgogne Vézelay', 'France')
# ('Vino de Calidad de Valtiendas', 'Spain')
# ('Mitterberg', 'Italy')
# ('Rivesaltes Rosé', 'France')
# ('Offida Rosso', 'Italy')
# ('Côtes de Montravel', 'France')
# ('Todi', 'Italy')
# ('Colli del Limbara', 'Italy')
# ('Catamarca', 'Argentina')
# ('Langhorne Creek-Limestone Coast', 'Australia')
# ("Coda di Volpe d'Irpinia", 'Italy')
# ('Squinzano', 'Italy')
# ('Barossa-Adelaide Hills', 'Australia')
# ('Monterey County-Napa County', 'US')
# ('Est! Est!! Est!!! di Montefiascone', 'Italy')
# ('Terrasses du Larzac', 'France')
# ('Apremont', 'France')
# ('San Diego County', 'US')
# ('Niagara Escarpment', 'US')
# ('Sonoma-Napa-Lake', 'US')
# ('Sonoma County-Santa Barbara County', 'US')
# ('Del Veneto', 'Italy')
# ('Bardolino Superiore', 'Italy')
# ('Paestum', 'Italy')

# %%
coord1[0]
# Out:
# [37.751005, 14.9934349]

# %%
len(coord1)
# Out:
# 1230

# %%
# append the co-ordiantes to the loc_df dataframe as a new column "coordiantes"
loc_df["coordinates"] = coord1
# Out:
# /Users/janakidevikora/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
loc_df.head(5)
# Out:
#               region_1 country                coordinates
# 0                 Etna   Italy    [37.751005, 14.9934349]
# 2    Willamette Valley      US  [44.942554, -122.9337615]
# 3  Lake Michigan Shore      US  [43.8348105, -85.0720293]
# 5              Navarra   Spain   [42.6953909, -1.6760691]
# 6             Vittoria   Italy  [35.4669667, -97.5428508]

# %%
# save the dataframe to csv
loc_df.to_csv('region_data.csv', index = False)
