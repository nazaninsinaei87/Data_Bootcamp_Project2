# %%
import requests
import json

import pandas as pd

file = "wine_data_new.csv"
### read data files into Data Frame
wine_df = pd.read_csv(file)

# %%
wine_df[(wine_df["country"]=="Argentina") & (wine_df["winery"] == "Chakana")]
# Out:
#           country                                        description  \
# 3263    Argentina  Earthy aromas of raisin, blackberry, barnyard ...
# 13615   Argentina  Rubbery, medicinal aromas suggest iodine and l...
# 16984   Argentina  Heavily toasted and loaded with black cherry a...
# 24532   Argentina  There's a sweet center to the bouquet, but sur...
# 25285   Argentina  Juicy and jumpy on the nose, but not sour. The...
# 32795   Argentina  Chunky and clunky on the nose, and unlike prev...
# 42963   Argentina  Basic white-fruit aromas are a bit dusty and y...
# 44136   Argentina  Dark-berry fruits, tomato and herbs make for a...
# 52162   Argentina  Chakana strikes again with this excellent valu...
# 57713   Argentina  Composed, well-oaked, earthy aromas of blackbe...
# 70843   Argentina  Spicy, herbal plum and berry aromas are a bit ...
# 77662   Argentina  Fairly smoky at first, with background aromas ...
# 81730   Argentina  Heavy oak and spice aromas are the primary gre...
# ...
